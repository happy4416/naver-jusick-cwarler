# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://finance.naver.com/sise/sise_market_sum.naver"
headers = {"User-Agent": "Mozilla/5.0"}

res = requests.get(url, headers=headers)
soup = BeautifulSoup(res.text, "html.parser")

rows = soup.select("table.type_2 tr")

# 데이터 저장용
ranks, names, prices, market_caps = [], [], [], []

for row in rows:
    cols = row.find_all("td")
    if len(cols) >= 7:
        name = cols[1].text.strip()
        price = cols[2].text.strip().replace(",", "")
        market_cap = cols[6].text.strip().replace(",", "")

        if name:  # 빈 행 제외
            ranks.append(len(ranks) + 1)
            names.append(name)
            prices.append(price)
            market_caps.append(market_cap)

# DataFrame 생성
df = pd.DataFrame({
    "순위": ranks,
    "종목명": names,
    "현재가": prices,
    "시가총액": market_caps
})

# %%
# 삼성전자 정보 필터링
samsung = df[df["종목명"] == "삼성전자"]

print("📊 전체 시가총액 상위 종목:")
df.head()
# Out:
# 📊 전체 시가총액 상위 종목:
#    순위       종목명      현재가     시가총액
# 0   1      삼성전자    61000  3610979
# 1   2    SK하이닉스   297000  2162167
# 2   3  삼성바이오로직스  1080000   768679
# 3   4  LG에너지솔루션   318000   744120
# 4   5      KB금융   116800   445548

# %%
# 삼성전자 정보 필터링
samsung = df[df["종목명"] == "삼성전자"]

print("\n📌 삼성전자 시가총액 순위:")
samsung if not samsung.empty else "삼성전자 없음!"
# Out:
# 📌 삼성전자 시가총액 순위:
#    순위   종목명    현재가     시가총액
# 0   1  삼성전자  61000  3610979
